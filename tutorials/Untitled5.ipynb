# %%
import networkx as nx
import matplotlib.pyplot as plt

G=nx.Graph()

#edge_list=list of edges where the weight 's' has been attributed to switches
edge_list=[(1,2,{'w':2}),(2,3,{'w':'s'}),(3,4,{'w':2}),(4,5,{'w':2}),(5,6,{'w':2}),(5,7,{'w':2}),(7,8,{'w':2}),
           (7,9,{'w':2}),(4,10,{'w':2}),(10,11,{'w':2}),(1,12,{'w':2}),(12,13,{'w':'s'}),(13,14,{'w':2}),(13,15,{'w':2}),(15,16,{'w':2}),(15,17,{'w':2}),(16,18,{'w':2}),(17,19,{'w':2}),(11,18,{'w':'s'}),
           (10,15,{'w':'s'}),(9,19,{'w':'s'}),(1,7,{'w':'s'})]
#edge_list=[(1,2,{'w':2}),(2,3,{'w':'s'}),(3,4,{'w':2}),(4,5,{'w':2}),(5,6,{'w':2}),(5,7,{'w':2}),(7,8,{'w':2}),(7,9,{'w':2}),(4,10,{'w':2}),(10,11,{'w':2}),(1,12,{'w':2}),(12,13,{'w':'s'}),(13,14,{'w':2}),(13,15,{'w':2}),(15,16,{'w':2}),(15,17,{'w':2}),(16,18,{'w':2}),(17,19,{'w':2}),(11,18,{'w':'s'})]

G.add_edges_from(edge_list)


#switches are colored in red and other edges in black
pos=nx.spring_layout(G)
colors=['k']*len(edge_list)
#switchL=list of switch edges
switchL=[]
i=0
for n1, n2, d in G.edges(data=True):
    if d['w']=='s':
        colors[i]='r'
        switchL.append((n1,n2))
    i=i+1
switchL2=list(sum(switchL,()))

nx.draw(G,pos,with_labels=True)
nx.draw_networkx_edges(G,edge_color=colors,pos=pos)
plt.axis("off")
plt.show()

#we create a new diconnected graph SG from G where we have removed all switches
Sedge_list=[]
SG=nx.Graph()
for n1, n2, d in G.edges(data=True):
    if d['w']!='s':
        Sedge_list.append((n1,n2))
SG.add_edges_from(Sedge_list)
Spos=nx.spring_layout(SG)
#we create a list with the connected components
cc=list(nx.connected_components(SG))
def convert(s):
    return list(map(lambda x: x, s))
ccl=[]
for x in range(len(cc)):
    ccl.append(convert(cc[x]))
#superN=list of super nodes. If they are in the same connected component they constitute the same super node superN. The label of each node is given by the list of the nodes of the original graph being the origin or the terminus of a switch edge.
superN=[]
for i in range(len(cc)):
    superN.append([])
    for a in switchL2:
        for b in ccl[i]:
            if a==b:
                superN[i].append(a)
superEdge_list=[]

superG=nx.MultiGraph()
for i in range(len(superN)):
    superG.add_node(str(superN[i]))

print("len(superN)",len(superN))
L=list(superG.nodes)
superEdge=[]
copySE=[]
print("switchL",switchL)


for f in range(len(switchL)):
    superEdge.append([])
    j1=0
    for j4 in range(len(superN)):
        for j5 in range(len(superN[j4])):
            if switchL[f][j1]==superN[j4][j5]:
                superEdge[f].append(superN[j4])
                j1=1
print("superEdge",superEdge)
for f in range(len(switchL)):
    copySE.append([])
    j1=0
    for j4 in range(len(superN)):
        for j5 in range(len(superN[j4])):
            if switchL[f][j1]==superN[j4][j5]:
                copySE[f].append(superN[j4])
                j1=1

multipleEdges=[]
#multipleEdgesStr=[]
singleEdges=[]
u=0
print("start",copySE)
i2=1
multipleEdges.append([])
#multipleEdgesStr.append([])
while len(copySE)>0 and i2<len(copySE):
    if copySE[0]==copySE[i2]:
        if len(multipleEdges[u])==0:
            multipleEdges.append([])
            multipleEdgesStr.append([])
        multipleEdges[u].append(copySE[0])
 #       a=str(copySE[0][0])+','+str(copySE[0][1])
#        print("a",a)
  #      multipleEdgesStr[u].append(a)
        copySE.remove(copySE[i2])
    else:
        if i2<len(copySE)-1:
            i2=i2+1
        else:
            if len(multipleEdges[u])>0:
                multipleEdges[u].append(copySE[0])
   #             multipleEdgesStr[u].append(str(copySE[0]))
                copySE.remove(copySE[0])
                u=u+1
                if len(copySE)>1:
                    i2=1
                else:
                    singleEdges.append(copySE[0])
            else:
                singleEdges.append(copySE[0])
multipleEdges.pop()
print("copySE",copySE)
print("multipleEdges",multipleEdges)
#print("multipleEdgesStr",multipleEdgesStr)
print("singleEdges",singleEdges)

for iE in range(len(superEdge)):
    superG.add_edge(str(superEdge[iE][0]),str(superEdge[iE][1]))#,weight=iE
print("superG.edges()",superG.edges())

superPos=nx.spring_layout(superG)
nx.draw(superG,superPos,with_labels=True)
ax = plt.gca()
for e in superG.edges:
    ax.annotate("",
                xy=superPos[e[0]], xycoords='data',
                xytext=superPos[e[1]], textcoords='data',
                arrowprops=dict(arrowstyle="-",shrinkA=5, shrinkB=5,patchA=None, patchB=None,connectionstyle="arc3,rad=rrr".replace('rrr',str(0.3*e[2])),))
plt.axis("off")
plt.show()
superGraphs=[]
g=len(multipleEdges[0])
for i in range(1,len(multipleEdges)):
   g=g*len(multipleEdges[i])

#for j in range(g):
#    superGraphs.append(nx.Graph())
#    for k in range(len(multipleEdges)): 
#        superGraphs[j].add_edge(str(multipleEdges[k][0][0]),str(multipleEdges[k][0][1]))
#    for k in range(len(singleEdges)):
#        superGraphs[j].add_edge(str(singleEdges[k][0]),str(singleEdges[k][1]))


superG2=nx.Graph(superG)

sp_trees=[]
#for j in range(len(superGraphs)):
for z in nx.SpanningTreeIterator(superG2):
    sp_tree=nx.Graph()
    sp_trees.append(z.edges())
    sp_tree.add_edges_from(z.edges())
    sp_tree_pos=nx.spring_layout(sp_tree)
  #  nx.draw(sp_tree,sp_tree_pos,with_labels=True)
  #  nx.draw_networkx_edges(sp_tree,pos=sp_tree_pos)
  #  plt.axis("off")
  #  plt.show()
i=0
for t in sp_trees:
    print(i)
    print(t)
    i=i+1
u=sp_trees[0]
print("list(sp_trees[0])[0]",list(sp_trees[0])[0])
print("list(sp_trees[0])[0][0]",list(sp_trees[0])[0][0])
print("list(sp_trees[0])[0][1]",list(sp_trees[0])[0][1])
print("list(sp_trees[0])[1][0]",list(sp_trees[0])[1][0])
print("list(sp_trees[0])[1][1]",list(sp_trees[0])[1][1])
print("list(sp_trees[1])[0]",list(sp_trees[1])[0])
print("list(sp_trees[1])[1]",list(sp_trees[1])[1])
print(multipleEdges)
print("multipleEdges[0][0]",multipleEdges[0][0])
print("list(sp_trees[0])[0][0]==str(multipleEdges[0][0][0]) and list(sp_trees[0])[0][1]==str(multipleEdges[0][0][1])",list(sp_trees[0])[0][0]==str(multipleEdges[0][0][0]) and list(sp_trees[0])[0][1]==str(multipleEdges[0][0][1]))
print(type(list(sp_trees[0])[0][0]),type(multipleEdges[0][0][0]))
print(list(sp_trees[0])[0][1]==str(multipleEdges[0][0][1]))
print(len(multipleEdges[1]))
print(len(sp_trees))
print(len(sp_trees[0]))
print(len(multipleEdges))
print("-----------------------------------------")
"""
for i in range(len(sp_trees)):
    for j in range(len(sp_trees[i])):
        for k in range(len(multipleEdges)):
            for a in multipleEdges[k]:
                print("i,j,list(sp_trees[i])[j][0]",i,j,list(sp_trees[i])[j][0])
                print("a[0]",a[0])
                print("i,j,list(sp_trees[i])[j][1]",i,j,list(sp_trees[i])[j][1])
                print("a[1]",a[1])
                if list(sp_trees[i])[j][0]==str(a[0]) and list(sp_trees[i])[j][1]==str(a[1]):
                    print("coucou")
                    k=len(multipleEdges)-1
                    print("k",k)
"""
for i in range(len(sp_trees)):
    for a in sp_trees[i]:
        #print("i",i)list(a)[0]=[1,2,12]
        for j in range(len(multipleEdges)):
            for b in multipleEdges[j]:
                if list(a)[0]==str(b[0]) and list(a)[1]==str(b[1]):
                    print("list(a)[0]",list(a)[0])
                    print("list(a)[1]",list(a)[1])
    
"""
for i in range(len(cc)):
    superN.append([])
    for a in switchL2:
        for b in ccl[i]:
            if a==b:
                superN[i].append(a)
"""
# Out:
# len(superN) 3
# switchL [(1, 7), (2, 3), (9, 19), (10, 15), (11, 18), (12, 13)]
# superEdge [[[1, 2, 12], [7, 3, 9, 10, 11]], [[1, 2, 12], [7, 3, 9, 10, 11]], [[7, 3, 9, 10, 11], [19, 15, 18, 13]], [[7, 3, 9, 10, 11], [19, 15, 18, 13]], [[7, 3, 9, 10, 11], [19, 15, 18, 13]], [[1, 2, 12], [19, 15, 18, 13]]]
# start [[[1, 2, 12], [7, 3, 9, 10, 11]], [[1, 2, 12], [7, 3, 9, 10, 11]], [[7, 3, 9, 10, 11], [19, 15, 18, 13]], [[7, 3, 9, 10, 11], [19, 15, 18, 13]], [[7, 3, 9, 10, 11], [19, 15, 18, 13]], [[1, 2, 12], [19, 15, 18, 13]]]
# copySE [[[1, 2, 12], [19, 15, 18, 13]]]
# multipleEdges [[[[1, 2, 12], [7, 3, 9, 10, 11]], [[1, 2, 12], [7, 3, 9, 10, 11]]], [[[7, 3, 9, 10, 11], [19, 15, 18, 13]], [[7, 3, 9, 10, 11], [19, 15, 18, 13]], [[7, 3, 9, 10, 11], [19, 15, 18, 13]]]]
# singleEdges [[[1, 2, 12], [19, 15, 18, 13]]]
# superG.edges() [('[1, 2, 12]', '[7, 3, 9, 10, 11]'), ('[1, 2, 12]', '[7, 3, 9, 10, 11]'), ('[1, 2, 12]', '[19, 15, 18, 13]'), ('[7, 3, 9, 10, 11]', '[19, 15, 18, 13]'), ('[7, 3, 9, 10, 11]', '[19, 15, 18, 13]'), ('[7, 3, 9, 10, 11]', '[19, 15, 18, 13]')]
# 0
# [('[1, 2, 12]', '[7, 3, 9, 10, 11]'), ('[1, 2, 12]', '[19, 15, 18, 13]')]
# 1
# [('[1, 2, 12]', '[19, 15, 18, 13]'), ('[7, 3, 9, 10, 11]', '[19, 15, 18, 13]')]
# 2
# [('[1, 2, 12]', '[7, 3, 9, 10, 11]'), ('[7, 3, 9, 10, 11]', '[19, 15, 18, 13]')]
# list(sp_trees[0])[0] ('[1, 2, 12]', '[7, 3, 9, 10, 11]')
# list(sp_trees[0])[0][0] [1, 2, 12]
# list(sp_trees[0])[0][1] [7, 3, 9, 10, 11]
# list(sp_trees[0])[1][0] [1, 2, 12]
# list(sp_trees[0])[1][1] [19, 15, 18, 13]
# list(sp_trees[1])[0] ('[1, 2, 12]', '[19, 15, 18, 13]')
# list(sp_trees[1])[1] ('[7, 3, 9, 10, 11]', '[19, 15, 18, 13]')
# [[[[1, 2, 12], [7, 3, 9, 10, 11]], [[1, 2, 12], [7, 3, 9, 10, 11]]], [[[7, 3, 9, 10, 11], [19, 15, 18, 13]], [[7, 3, 9, 10, 11], [19, 15, 18, 13]], [[7, 3, 9, 10, 11], [19, 15, 18, 13]]]]
# multipleEdges[0][0] [[1, 2, 12], [7, 3, 9, 10, 11]]
# list(sp_trees[0])[0][0]==str(multipleEdges[0][0][0]) and list(sp_trees[0])[0][1]==str(multipleEdges[0][0][1]) True
# <class 'str'> <class 'list'>
# True
# 3
# 3
# 2
# 2
# -----------------------------------------
# list(a)[0] [1, 2, 12]
# list(a)[1] [7, 3, 9, 10, 11]
# list(a)[0] [1, 2, 12]
# list(a)[1] [7, 3, 9, 10, 11]
# list(a)[0] [7, 3, 9, 10, 11]
# list(a)[1] [19, 15, 18, 13]
# list(a)[0] [7, 3, 9, 10, 11]
# list(a)[1] [19, 15, 18, 13]
# list(a)[0] [7, 3, 9, 10, 11]
# list(a)[1] [19, 15, 18, 13]
# list(a)[0] [1, 2, 12]
# list(a)[1] [7, 3, 9, 10, 11]
# list(a)[0] [1, 2, 12]
# list(a)[1] [7, 3, 9, 10, 11]
# list(a)[0] [7, 3, 9, 10, 11]
# list(a)[1] [19, 15, 18, 13]
# list(a)[0] [7, 3, 9, 10, 11]
# list(a)[1] [19, 15, 18, 13]
# list(a)[0] [7, 3, 9, 10, 11]
# list(a)[1] [19, 15, 18, 13]
# '\nfor i in range(len(cc)):\n    superN.append([])\n    for a in switchL2:\n        for b in ccl[i]:\n            if a==b:\n                superN[i].append(a)\n'
